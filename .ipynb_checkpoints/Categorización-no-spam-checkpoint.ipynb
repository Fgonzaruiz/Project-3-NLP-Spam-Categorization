# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import pickle

# %%
with open("model.pkl", 'rb') as file:
    model = pickle.load(file)

# %%
with open("vectorizer.pkl", 'rb') as file:
    vectorizer_clf = pickle.load(file)

# %%
df = pd.read_csv('processed_emails.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11300 entries, 0 to 11299
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   text          11300 non-null  object
#  1   spam          11300 non-null  int64
#  2   email_length  11300 non-null  int64
#  3   text_prepr    11288 non-null  object
# dtypes: int64(2), object(2)
# memory usage: 353.2+ KB

# %%
df
# Out:
#                                                     text  spam  email_length  \
# 0      Subject: naturally irresistible your corporate...     1          1484
# 1      Subject: the stock trading gunslinger  fanny i...     1           598
# 2      Subject: unbelievable new homes made easy  im ...     1           448
# 3      Subject: 4 color printing special  request add...     1           500
# 4      Subject: do not have money , get software cds ...     1           235
# ...                                                  ...   ...           ...
# 11295  This is the 2nd time we have tried 2 contact u...     1           160
# 11296               Will ü b going to esplanade fr home?     0            36
# 11297  Pity, * was in mood for that. So...any other s...     0            57
# 11298  The guy did some bitching but I acted like i'd...     0           125
# 11299                         Rofl. Its true to its name     0            26
#
#                                               text_prepr
# 0      subject naturally irresistible corporate ident...
# 1      subject stock trading gunslinger fanny merrill...
# 2      subject unbelievable new homes made easy im wa...
# 3      subject color printing special request additio...
# 4      subject money get software cds software compat...
# ...                                                  ...
# 11295  time tried contact u pound prize claim easy ca...
# 11296                        ü b going esplanade fr home
# 11297                              pity mood suggestions
# 11298  guy bitching acted like interested buying some...
# 11299                                     rofl true name
#
# [11300 rows x 4 columns]

# %%
df['text_prepr'].dropna('', inplace=True)
# Out:
# C:\Users\Fgonz\AppData\Local\Temp\ipykernel_2960\2889498028.py:1: FutureWarning: In a future version of pandas all arguments of Series.dropna will be keyword-only.
#   df['text_prepr'].dropna('', inplace=True)

# %%
df_no_spam=df[df["spam"]==0]

# %%
df_no_spam.dropna(subset="text_prepr", inplace=True)
# Out:
# C:\Users\Fgonz\AppData\Local\Temp\ipykernel_2960\1258488278.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_no_spam.dropna(subset="text_prepr", inplace=True)

# %%
vectorizer_kmeans = TfidfVectorizer()
X = vectorizer_kmeans.fit_transform(df_no_spam['text_prepr'])

# %%
vectorizer_kmeans.get_feature_names()
# Out:
# C:\Users\Fgonz\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# ['aa',
#  'aaa',
#  'aaaenerfax',
#  'aadedeji',
#  'aagrawal',
#  'aah',
#  'aaldous',
#  'aanalysis',
#  'aaniye',
#  'aaooooright',
#  'aaron',
#  'aathi',
#  'ab',
#  'abacus',
#  'abahy',
#  'abandon',
#  'abandoned',
#  'abandonment',
#  'abarr',
#  'abb',
#  'abbey',
#  'abbott',
#  'abbreviated',
#  'abbreviation',
#  'abc',
#  'abdelnour',
#  'abdomen',
#  'abdul',
#  'abdullah',
#  'abeg',
#  'abel',
#  'abello',
#  'abernathy',
#  'abetted',
#  'abeyance',
#  'abhay',
#  'abi',
#  'abide',
#  'abilities',
#  'ability',
#  'abiola',
#  'abitibi',
#  'abj',
#  'abklaeren',
#  'abl',
#  'able',
#  'abler',
#  'abliged',
#  'ablx',
#  'abn',
#  'abnormal',
#  'abnormally',
#  'aboard',
#  'abolish',
#  'abook',
#  'aboriginal',
#  'abormalities',
#  'abort',
#  'aboutas',
#  'abouts',
#  'abovenet',
#  'abr',
#  'abraham',
#  'abramowicz',
#  'abrams',
#  'abrasive',
#  'abreast',
#  'abreo',
#  'abridged',
#  'abroad',
#  'abs',
#  'absence',
#  'absense',
#  'absent',
#  'absolute',
#  'absolutely',
#  'absolutly',
#  'absolved',
#  'absorb',
#  'absorbing',
#  'absorbowac',
#  'absorbs',
#  'absorption',
#  'absoutely',
#  'abstained',
#  'abstract',
#  'abstracts',
#  'abstruse',
#  'absurd',
#  'abt',
#  'abu',
#  'abundance',
#  'abundant',
#  'abundantly',
#  'aburo',
#  'abuse',
#  'abusers',
#  'abutler',
#  'aby',
#  'ac',
#  'acacia',
#  'academe',
#  'academia',
#  'academic',
#  'academically',
#  'academicians',
#  'academics',
#  'academy',
#  'acadrep',
#  'acc',
#  'accelerate',
#  'accelerated',
#  'accelerating',
#  'acceleration',
#  'accellerate',
#  'accent',
#  'accentuates',
#  'accenture',
#  'accept',
#  'acceptable',
#  'acceptance',
#  'accepted',
#  'accepting',
#  'accepts',
#  'acces',
#  'access',
#  'accessed',
#  'accessenergy',
#  'accessibility',
#  'accessible',
#  'accessing',
#  'accidant',
#  'accident',
#  'accidentally',
#  'accidents',
#  'acclaimed',
#  'accommodate',
#  'accommodates',
#  'accommodating',
#  'accommodation',
#  'accommodations',
#  'accomodate',
#  'accomodated',
#  'accomodates',
#  'accomodating',
#  'accomodation',
#  'accomodations',
#  'accomodative',
#  'accompanied',
#  'accompanies',
#  'accompany',
#  'accompanying',
#  'accomplish',
#  'accomplished',
#  'accomplishemnts',
#  'accomplishing',
#  'accomplishment',
#  'accomplishments',
#  'accord',
#  'accordance',
#  'accordin',
#  'according',
#  'accordingly',
#  'account',
#  'accountability',
#  'accountable',
#  'accountant',
#  'accountants',
#  'accounted',
#  'accounting',
#  'accounton',
#  'accounts',
#  'accreditation',
#  'accrual',
#  'accruals',
#  'accrue',
#  'accruing',
#  'accumulated',
#  'accumulating',
#  'accumulation',
#  'accumulations',
#  'accuracy',
#  'accurate',
#  'accurately',
#  'accusation',
#  'accuse',
#  'accused',
#  'accuweather',
#  'accuwx',
#  'ace',
#  'ach',
#  'achan',
#  'ache',
#  'achievable',
#  'achieve',
#  'achieved',
#  'achievement',
#  'achievements',
#  'achieves',
#  'achieving',
#  'acid',
#  'acitivities',
#  'ack',
#  'acknowledge',
#  'acknowledged',
#  'acknowledgement',
#  'acknowledgements',
#  'acknowledges',
#  'acknowledging',
#  'acl',
#  'acnt',
#  'aco',
#  'acpw',
#  'acquaint',
#  'acquaintance',
#  'acquainted',
#  'acquiescence',
#  'acquire',
#  'acquired',
#  'acquires',
#  'acquiring',
#  'acquisition',
#  'acquisitions',
#  'acrobat',
#  'acronyms',
#  'across',
#  'act',
#  'acted',
#  'actin',
#  'acting',
#  'action',
#  'actions',
#  'activate',
#  'activated',
#  'active',
#  'actively',
#  'activities',
#  'activity',
#  'actor',
#  'acts',
#  'actual',
#  'actuality',
#  'actually',
#  'actuals',
#  'actuarial',
#  'actuaries',
#  'actuary',
#  'acucmulated',
#  'acumen',
#  'acutal',
#  'acute',
#  'acxiom',
#  'ad',
#  'adam',
#  'adamant',
#  'adamantly',
#  'adambob',
#  'adamik',
#  'adams',
#  'adapt',
#  'adapted',
#  'adapter',
#  'adapting',
#  'adaptive',
#  'adapts',
#  'adauction',
#  'add',
#  'added',
#  'addendum',
#  'addicted',
#  'addie',
#  'addin',
#  'adding',
#  'addiontionally',
#  'addition',
#  'additional',
#  'additionally',
#  'additionnal',
#  'additions',
#  'additive',
#  'additivity',
#  'additonal',
#  'addr',
#  'address',
#  'addressed',
#  'addressee',
#  'addressees',
#  'addresses',
#  'addressgood',
#  'addressing',
#  'addressl',
#  'adds',
#  'addtion',
#  'adducing',
#  'adedamola',
#  'adedeji',
#  'adelaide',
#  'adenauera',
#  'adenda',
#  'adept',
#  'adequacy',
#  'adequate',
#  'adequately',
#  'adewale',
#  'adgas',
#  'adhadwal',
#  'adhar',
#  'adhere',
#  'adhered',
#  'adherence',
#  'adheres',
#  'adhering',
#  'adhesive',
#  'adi',
#  'adib',
#  'adinfo',
#  'adjacent',
#  'adjected',
#  'adjesting',
#  'adjohnso',
#  'adjourn',
#  'adjournment',
#  'adjourns',
#  'adjunct',
#  'adjust',
#  'adjustable',
#  'adjusted',
#  'adjusting',
#  'adjustment',
#  'adjustments',
#  'adjusts',
#  'adler',
#  'adm',
#  'admin',
#  'administer',
#  'administered',
#  'administering',
#  'administers',
#  'administration',
#  'administrations',
#  'administrative',
#  'administratively',
#  'administrator',
#  'administrators',
#  'adminitrative',
#  'admins',
#  'adminsitrative',
#  'adminstrative',
#  'admirably',
#  'admire',
#  'admired',
#  'admissible',
#  'admission',
#  'admissions',
#  'admit',
#  'admits',
#  'admitted',
#  'adnan',
#  'adnoc',
#  'adobe',
#  'adonna',
#  'adopt',
#  'adopted',
#  'adopting',
#  'adoption',
#  'adopts',
#  'adore',
#  'adoring',
#  'adovor',
#  'adres',
#  'adress',
#  'adrian',
#  'adriana',
#  'adrianne',
#  'adrink',
#  'adrrf',
#  'adsense',
#  'aduit',
#  'adult',
#  'adults',
#  'adupont',
#  'advance',
#  'advanced',
#  'advancement',
#  'advances',
#  'advancing',
#  'advancve',
#  'advantage',
#  'advantages',
#  'advent',
#  'adventure',
#  'adventuring',
#  'adventurous',
#  'adverse',
#  'advertise',
#  'advertised',
#  'advertisement',
#  'advertising',
#  'advice',
#  'advisable',
#  'advise',
#  'advised',
#  'adviser',
#  'advisers',
#  'advises',
#  'advising',
#  'advisor',
#  'advisors',
#  'advisory',
#  'advocacy',
#  'advocate',
#  'advocates',
#  'advocating',
#  'ae',
#  'aeasterby',
#  'aeecl',
#  'aegis',
#  'aep',
#  'aer',
#  'aeremenko',
#  'aero',
#  'aeron',
#  'aeronautic',
#  'aeronautical',
#  'aeronautics',
#  'aerons',
#  'aeroplane',
#  'aerpac',
#  'aesop',
#  'aesp',
#  'af',
#  'afa',
#  'afc',
#  'afew',
#  'affair',
#  'affairs',
#  'affect',
#  'affected',
#  'affecteusement',
#  'affecting',
#  'affection',
#  'affectionate',
#  'affections',
#  'affects',
#  'affidavit',
#  'affiliate',
#  'affiliated',
#  'affiliates',
#  'affiliation',
#  'affiliations',
#  'affirmative',
#  'affirmed',
#  'affluent',
#  'afford',
#  'affordable',
#  'afforded',
#  'affords',
#  'afghanistan',
#  'afire',
#  'aford',
#  'aforementioned',
#  'afraid',
#  'africa',
#  'african',
#  'aft',
#  'aftermath',
#  'afternon',
#  'afternoon',
#  'afternoondc',
#  'afternoons',
#  'afterthought',
#  'afterwards',
#  'aftr',
#  'ag',
#  'aga',
#  'againstyear',
#  'agalla',
#  'agarwal',
#  'agarwalla',
#  'agarwallah',
#  'agato',
#  'agc',
#  'agdesteen',
#  'age',
#  'aged',
#  'agencies',
#  'agency',
#  'agenda',
#  'agendal',
#  'agendas',
#  'agent',
#  'agents',
#  'agentur',
#  'agerhardt',
#  'ages',
#  'agg',
#  'aggrandisement',
#  'aggregate',
#  'aggregated',
#  'aggregates',
#  'aggregating',
#  'aggregation',
#  'aggregator',
#  'aggressive',
#  'aggressively',
#  'aghh',
#  'agidhane',
#  'agin',
#  'aging',
#  'agitate',
#  'aglife',
#  'agnes',
#  'agnihotri',
#  'ago',
#  'agrawal',
#  'agree',
#  'agreeable',
#  'agreed',
#  'agreeing',
#  'agreelment',
#  'agreement',
#  'agreements',
#  'agrees',
#  'agressively',
#  'agresti',
#  'agri',
#  'agricaltural',
#  'agricultural',
#  'agriculture',
#  'agriculturists',
#  'aguilar',
#  'ah',
#  'aha',
#  'ahad',
#  'ahamer',
#  'ahc',
#  'ahead',
#  'aherns',
#  'ahhh',
#  'ahhhh',
#  'ahi',
#  'ahmad',
#  'ahmedabad',
#  'ahn',
#  'ahold',
#  'ai',
#  'aid',
#  'aidan',
#  'aide',
#  'aided',
#  'aides',
#  'aids',
#  'aiesec',
#  'aieseec',
#  'aig',
#  'aight',
#  'ailing',
#  'ailures',
#  'aim',
#  'aimed',
#  'aimeedodson',
#  'aimfunds',
#  'aiming',
#  'aimone',
#  'aims',
#  'ainsley',
#  'aint',
#  'air',
#  'airam',
#  'airbill',
#  'aircraft',
#  'aircrafts',
#  'aireal',
#  'aired',
#  'aires',
#  'airfaire',
#  'airfare',
#  'airfares',
#  'airgas',
#  'airline',
#  'airlines',
#  'airliquide',
#  'airplane',
#  'airport',
#  'airtel',
#  'aisa',
#  'aisaac',
#  'aisha',
#  'aisle',
#  'ait',
#  'aix',
#  'aiya',
#  'aiyah',
#  'aiyar',
#  'aiyo',
#  'ajay',
#  'ajello',
#  'ajimenez',
#  'ajit',
#  'ajith',
#  'ajnam',
#  'ajo',
#  'ak',
#  'aka',
#  'akaike',
#  'akamai',
#  'akdwyer',
#  'aked',
#  'akhave',
#  'akin',
#  'akllp',
#  'aktualnie',
#  'al',
#  'alabama',
#  'alain',
#  'alaina',
#  'alaipayuthe',
#  'alamo',
#  'alamonsoff',
#  'alamos',
#  'alan',
#  'alang',
#  'alarms',
#  'alaska',
#  'alaskan',
#  'alaw',
#  'albanis',
#  'albeit',
#  'albert',
#  'alberta',
#  'alberto',
#  'albertson',
#  'albi',
#  'albion',
#  'albo',
#  'albrecht',
#  'album',
#  'alcantara',
#  'alcar',
#  'alcoa',
#  'alcohol',
#  'alden',
#  'alder',
#  'aldous',
#  'aldrine',
#  'ale',
#  'alea',
#  'alec',
#  'alejandra',
#  'alek',
#  'aleksander',
#  'aleksandra',
#  'alert',
#  'alerted',
#  'alerts',
#  'aletter',
#  'alev',
#  'alex',
#  'alexana',
#  'alexander',
#  'alexandria',
#  'alexey',
#  'alexios',
#  'alexis',
#  'alexmann',
#  'aley',
#  'alff',
#  'alford',
#  'alfred',
#  'alfredo',
#  'algebra',
#  'algorithm',
#  'algorithmic',
#  'algorithmical',
#  'algorithmics',
#  'algorithmist',
#  'algorithms',
#  'alhamd',
#  'ali',
#  'alian',
#  'alibi',
#  'alice',
#  'alicia',
#  'aliens',
#  'align',
#  'alignment',
#  'alike',
#  'alisa',
#  'alison',
#  'alive',
#  'alkhayat',
#  'alkiem',
#  'alla',
#  'allah',
#  'allalo',
#  'allan',
#  'allario',
#  'allayannis',
#  'allayed',
#  'allday',
#  'alldo',
#  'alle',
#  'allegation',
#  'allegations',
#  'alleged',
#  'allegheny',
#  'alleging',
#  'allen',
#  'allens',
#  'allerdings',
#  'alleviate',
#  'alliance',
#  'allianceexpressl',
#  'alliances',
#  'alliant',
#  'allianz',
#  'alliece',
#  'allied',
#  'allison',
#  'alll',
#  'allo',
#  'allocate',
#  'allocated',
#  'allocating',
#  'allocation',
#  'allocations',
#  'allotted',
#  'allow',
#  'allowance',
#  'allowances',
#  'allowed',
#  'allowing',
#  'allows',
#  'alloy',
#  'allright',
#  'allude',
#  'alluded',
#  'alluding',
#  'allure',
#  'allusions',
#  'allyannis',
#  'alm',
#  'alma',
#  'almaty',
#  'almazan',
#  'almelo',
#  'almost',
#  'alon',
#  'alone',
#  'along',
#  'alongside',
#  'alongwith',
#  'alonso',
#  'alot',
#  'alp',
#  'alpbach',
#  'alpbacher',
#  'alpha',
#  'alphabetical',
#  'alphabetically',
#  'alphanumeric',
#  'alpharetta',
#  'already',
#  'alright',
#  'alrite',
#  'als',
#  'also',
#  'alst',
#  'alstom',
#  'alstrom',
#  'alt',
#  'altamont',
#  'alter',
#  'alterations',
#  'altered',
#  'alternate',
#  'alternately',
#  'alternative',
#  'alternatively',
#  'alternatives',
#  'alternatywne',
#  'althea',
#  'although',
#  'althought',
#  'althrough',
#  'alto',
#  'altogether',
#  'altos',
#  'altosmgmt',
#  'altra',
#  'altranet',
#  'alu',
#  'alum',
#  'aluminium',
#  'aluminum',
#  'alumni',
#  'alums',
#  'alvarado',
#  'alvarez',
#  'alvin',
#  'alwa',
#  'always',
#  'alwyas',
#  'alwys',
#  'alynch',
#  'alyse',
#  'alyson',
#  'alysonfisher',
#  'amadeus',
#  'amanda',
#  'amandam',
#  'amander',
#  'amarger',
#  'amarillo',
#  'amazed',
#  'amazing',
#  'amazingly',
#  'amazon',
#  'ambani',
#  'ambassador',
#  'ambiguous',
#  'ambition',
#  'ambitions',
#  'ambitious',
#  'ambler',
#  'ambrith',
#  'ambroshia',
#  'amc',
#  'amenable',
#  'amend',
#  'amended',
#  'amendements',
#  'amending',
#  'amendment',
#  'amendments',
#  'amends',
#  'amer',
#  'amerada',
#  'ameren',
#  'america',
#  'american',
#  'americancentury',
#  'americans',
#  'americas',
#  'ameriflash',
#  'ameryki',
#  'ames',
#  'ametz',
#  'amex',
#  'amh',
#  'amherst',
#  'ami',
#  'amicable',
#  'amicably',
#  'amicaliz',
#  'amidst',
#  'amifs',
#  'amigos',
#  'amin',
#  'amir',
#  'amiry',
#  'amis',
#  'amit',
#  'amitava',
#  'amitavas',
#  'amititava',
#  'amk',
#  'ammae',
#  'ammo',
#  'ammonia',
#  'ammunition',
#  'amnow',
#  'amoco',
#  'amoine',
#  'among',
#  'amongst',
#  'amore',
#  'amos',
#  'amoung',
#  'amount',
#  'amounting',
#  'amounts',
#  'amp',
#  'ampl',
#  'ample',
#  'amplikater',
#  'amr',
#  'amram',
#  'amrca',
#  'amrita',
#  'amro',
#  'amrresearch',
#  'ams',
#  'amson',
#  'amsterdam',
#  'amt',
#  'amul',
#  'amused',
#  'amusing',
#  'amy',
#  'amyn',
#  'ana',
#  'anad',
#  'anadarko',
#  'anadian',
#  'anal',
#  'anala',
#  'analiza',
#  'analizy',
#  'analog',
#  'analogous',
#  'analogy',
#  'analyse',
#  'analysed',
#  'analyses',
#  'analysing',
#  'analysis',
#  'analysists',
#  'analyst',
#  'analystical',
#  'analysts',
#  'analytic',
#  'analytica',
#  'analytical',
#  'analytics',
#  'analyze',
#  'analyzed',
#  'analyzes',
#  'analyzing',
#  'analzing',
#  'anand',
#  'ananda',
#  'anaylst',
#  'anbei',
#  'ancestry',
#  'anchor',
#  'ancillary',
#  'andersen',
#  'anderson',
#  'andersson',
#  'andes',
#  'andras',
#  'andre',
#  'andrea',
#  'andreas',
#  'andrei',
#  'andres',
#  'andrew',
#  'andrews',
#  'andriole',
#  'andromeda',
#  'andros',
#  'andrzej',
#  'andrzeju',
#  'andthere',
#  'andy',
#  'anecdotal',
#  'anecdotally',
#  'anecdotes',
#  'angel',
#  'angela',
#  'angeles',
#  'angelfire',
#  'angelic',
#  'angelica',
#  'angelides',
#  'angelika',
#  'angelina',
#  'angelova',
#  'angels',
#  'anger',
#  'angibt',
#  'angie',
#  'angielski',
#  'angielskiej',
#  'angielskim',
#  'angielsku',
#  'angle',
#  'anglelides',
#  'angles',
#  'anglo',
#  'angry',
#  'anguel',
#  'anguiano',
#  'angus',
#  'anh',
#  'aniem',
#  'anil',
#  'animal',
#  'animation',
#  'animations',
#  'anita',
#  'anitha',
#  'anjam',
#  'anjie',
#  'anjola',
#  'ankunft',
#  'anl',
#  'anlysis',
#  'anlytical',
#  ...]

# %%
# SSE = []
# for cluster in range(1,10):
#     kmeans = KMeans(n_clusters = cluster, random_state=0)
#     kmeans.fit(X)
#     SSE.append(kmeans.inertia_)

# %%
# plt.plot(range(1,10),SSE)
# plt.title('Método del codo')
# plt.xlabel('Número de clusters')
# plt.ylabel('SSE')
# plt.show()

# %%
def hacer_clustering(dataframe, n_clusters):
    dataframe = dataframe[dataframe['spam'] == 0].dropna(subset=['text_prepr'])
    
    mensajes_no_spam = dataframe['text_prepr']
    
    X = vectorizer_kmeans.fit_transform(mensajes_no_spam)
    
    kmeans = KMeans(n_clusters=n_clusters)
    kmeans.fit(X)
    
    grupos = kmeans.predict(X)
    serie_grupos = pd.Series(grupos, name='group', index=mensajes_no_spam.index)
    
    return dataframe.assign(group=serie_grupos), kmeans

# %%
df
# Out:
#                                                     text  spam  email_length  \
# 0      Subject: naturally irresistible your corporate...     1          1484
# 1      Subject: the stock trading gunslinger  fanny i...     1           598
# 2      Subject: unbelievable new homes made easy  im ...     1           448
# 3      Subject: 4 color printing special  request add...     1           500
# 4      Subject: do not have money , get software cds ...     1           235
# ...                                                  ...   ...           ...
# 11295  This is the 2nd time we have tried 2 contact u...     1           160
# 11296               Will ü b going to esplanade fr home?     0            36
# 11297  Pity, * was in mood for that. So...any other s...     0            57
# 11298  The guy did some bitching but I acted like i'd...     0           125
# 11299                         Rofl. Its true to its name     0            26
#
#                                               text_prepr
# 0      subject naturally irresistible corporate ident...
# 1      subject stock trading gunslinger fanny merrill...
# 2      subject unbelievable new homes made easy im wa...
# 3      subject color printing special request additio...
# 4      subject money get software cds software compat...
# ...                                                  ...
# 11295  time tried contact u pound prize claim easy ca...
# 11296                        ü b going esplanade fr home
# 11297                              pity mood suggestions
# 11298  guy bitching acted like interested buying some...
# 11299                                     rofl true name
#
# [11300 rows x 4 columns]

# %%
df_grupos0, kmeans=hacer_clustering(df,5)

# %%
df_grupos1=df_grupos0.dropna(subset="group", inplace=False)

# %%
df_grupos1
# Out:
#                                                     text  spam  email_length  \
# 1368   Subject: hello guys ,  i ' m " bugging you " f...     0          1188
# 1369   Subject: sacramento weather station  fyi  - - ...     0          1997
# 1370   Subject: from the enron india newsdesk - jan 1...     0          7902
# 1371   Subject: re : powerisk 2001 - your invitation ...     0          3644
# 1372   Subject: re : resco database and customer capt...     0          5535
# ...                                                  ...   ...           ...
# 11293                                       Huh y lei...     0            12
# 11296               Will ü b going to esplanade fr home?     0            36
# 11297  Pity, * was in mood for that. So...any other s...     0            57
# 11298  The guy did some bitching but I acted like i'd...     0           125
# 11299                         Rofl. Its true to its name     0            26
#
#                                               text_prepr  group
# 1368   subject hello guys bugging completed questionn...      0
# 1369   subject sacramento weather station fyi forward...      4
# 1370   subject enron india newsdesk jan th newsclips ...      0
# 1371   subject powerisk invitation angelika thanks in...      0
# 1372   subject resco database customer capture steve ...      0
# ...                                                  ...    ...
# 11293                                            huh lei      2
# 11296                        ü b going esplanade fr home      2
# 11297                              pity mood suggestions      2
# 11298  guy bitching acted like interested buying some...      2
# 11299                                     rofl true name      2
#
# [9174 rows x 5 columns]

# %%
def hacer_wordcloud(dataframe, n_clusters):
    for i in range(n_clusters):
        messages_group = dataframe[dataframe['group'] == i]['text_prepr'].str.cat(sep=' ')
        
        wordcloud = WordCloud(width=400, height=400, min_font_size=10).generate(messages_group)
        
        plt.figure(figsize=(4, 4), facecolor=None)
        plt.imshow(wordcloud)
        plt.axis("off")
        plt.tight_layout(pad=0)
        
        plt.show()

# %%
hacer_wordcloud(df_grupos1,5)

# %%
def predecir_grupo_spam(mensaje, vectorizer_clf, vectorizer_kmeans, kmeans, model):
    # Predecir la probabilidad de que sea spam
    X_spam = vectorizer_clf.transform([mensaje])
    y_pred_spam = model.predict(X_spam)
    if y_pred_spam[0] > 0.5:
        return 'Spam'
    else:
        # Predecir al grupo al que pertenece
#         Cargar vectorizer_kmeans
        
        mensaje_vect = vectorizer_kmeans.transform([mensaje])
        label = kmeans.predict(mensaje_vect)[0]
        return 'No es spam, pertenece al grupo: {}'.format(label)

# %%
mensaje = input("Introduce el mensaje: ")
print(predecir_grupo_spam(mensaje, vectorizer_clf, vectorizer_kmeans, kmeans, model))
# Out:
# Introduce el mensaje: ü b going esplanade fr home
# No es spam, pertenece al grupo: 2
